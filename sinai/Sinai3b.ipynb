# %% [markdown]
# Goals:
# 1. Move "foundational" code to file to allow us to focus on the experiment.
# 2. Search for best launch point given a fixed angle

# %%
draw_hist(pos=result[1], t=result[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\google drive\Math\brazil\code\sinai\Sinai_billiard_defs.py in <module>()
# ----> 1 draw_hist(pos=result[1], t=result[0])
#
# NameError: name 'result' is not defined

# %%
side = 10
scatter_radius = 4
particle_radius = 2
num_walls = 5
hole = 3
max_steps = 1000
seed = 19

# %run -i Sinai_billiard_defs.py

X = np.linspace(-hole_range, hole_range, 1000)
theta = np.pi/10
y = -y_range
speed = 1.0

num_collisions = [run_trial(x, y, speed, theta)[0] for x in X]

# %%
import matplotlib.pyplot as plt
plt.plot(X, num_collisions)
plt.xlabel('x')
plt.ylabel('number of collisions')
plt.show()
